# %%
from matplotlib import pyplot as plt
import numpy as np
import os
# %matplotlib notebook

# %%
e = np.arange(-1.5,1.50,.1)
def a_domains(x):
    return np.where(x<-1,0,np.where(x<1,100*(1+x)/2,100))
    
plt.figure(figsize=(6,3))
plt.plot(e,a_domains(e))
plt.xlabel(r'$\epsilon/\epsilon_s(T)$')
plt.ylabel('Proportion of "a" domains (%)')
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, 'Proportion of "a" domains (%)')

# %%
os.chdir(r'C:\Users\Pierre\Desktop\Postdoc\Bibliographic_resources\Articles_FeSC\FeSe\FeSe_nematicity\Bartlett2021')

# %%
plt.savefig('2021-04-21_a_domains_vs_strain.png', bbox_inches='tight', dpi=150)
